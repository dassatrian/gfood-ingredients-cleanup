# %% [markdown]
# ## Goal: have a script to run from start to finish that will call ingredients endpoint and upload ingredients to Cosmos DB

# %%
# reading in packages
import pandas as pd
import numpy as np
import re
import json
import requests

# %%
# reading in databases
food_details = pd.read_excel('raw_data/Release 1 - Food details file.xlsx')

food_nutrients_excel = pd.ExcelFile('raw_data/Release 1 - Food nutrient database.xlsx')
food_nutrients = pd.read_excel(food_nutrients_excel,'All solids & liquids per 100g')

food_measures = pd.read_excel('raw_data/Release 1 - Measures file.xlsx')
food_recipe = pd.read_excel('raw_data/Release 1 - Recipe file.xlsx')

food_emissions = pd.read_excel('raw_data/emissions.xlsx')
food_categories = pd.read_excel('raw_data/categories.xlsx')

initial_classification = pd.read_csv('raw_data/initial_classification.csv')

# to store all of the food product classifications, now we can drop Classification Name from the food database
food_classification = food_details[['Classification ID', 'Classification Name']].copy()
food_classification.drop_duplicates(inplace = True)

# need to fix up the merged columns (ie. make the "Unnamed" column match the previous column name) and remove the units row (make a part of column name)
regex = re.compile(r'Unnamed') # regex to find the "Unnamed" columns

old_columns = list(food_nutrients.columns) # list of existing columns
units = food_nutrients[0:1].values[0] # list of the unit row
new_columns = [] # empty list to store the new column values

for each in range(len(old_columns)):
    if re.search(regex, food_nutrients.columns[each]): # ie. find the column that is "unnamed"
        try:
            new_columns.append(old_columns[each-1] + ' (in ' + units[each] + ')') # take the previous column name and add units
        except:
            new_columns.append(old_columns[each-1]) # if you can't add the units, just keep the column
    else: # ie. column is not "unnamed"
        try:
            new_columns.append(old_columns[each] + ' (in ' + units[each] + ')')
        except:
            new_columns.append(old_columns[each])
    
food_nutrients.rename(columns = dict(zip(old_columns, new_columns)), inplace = True) # rename the columns
food_nutrients.drop(0, axis = 0, inplace = True) # drop the unit row
food_nutrients.reset_index(drop = True, inplace = True) # reset the index

# %% [markdown]
# ## Information about our datasets
# * food_details # information about the ingredient
# * food_nutrients # nutritional information about the ingredient
# * food_measures # information about the measures of ingredients
# * food_recipe # a list of recipes (useless)
# * food_emissions # ghg emissions table
# * food_categories # HSR calculation
# * food_classification # food classifications which came with the dataset
#
# ## Joining on the Initial Classification (so that we can calculate HSR rating and emissions)
# HSR calculation and GHG emissions relies on having a particular classification to a group. Since our open data sets don't have these groups, I have had to manually create an initial_classification file, which I have done at a broad category level, and will apply down to the individual ingredients. Not accurate, but quick.

# %%
food_details = food_details.merge(initial_classification, on = 'Classification ID', how = 'left')

# %% [markdown]
# ## Joining nutritional data and food_details so we can calculate HSR

# %%
food_details = food_details.merge(food_nutrients, on = 'Public Food Key')

# %% [markdown]
# ## Calculating HSR for Ingredients
# Now that food_details have emission_id, hsr_id as well as all nutritional data we can calculate HSR rating for each ingredient (where available), and also GHG emissions (approximate)

# %%
# Reading in hsr tables
hsr_table_1 = pd.read_csv('raw_data/hsr_table_1.csv')
hsr_table_2 = pd.read_csv('raw_data/hsr_table_2.csv')
hsr_table_3 = pd.read_csv('raw_data/hsr_table_3.csv')
hsr_table_4 = pd.read_csv('raw_data/hsr_table_4.csv')

# function to find the closest value in a list
def get_closest_value(arr, target):
    n = len(arr)
    left = 0
    right = n - 1
    mid = 0

    # edge case - last or above all
    if target >= arr[n - 1]:
        return arr[n - 1]
    # edge case - first or below all
    if target <= arr[0]:
        return arr[0]
    # BSearch solution: Time & Space: Log(N)

    while left < right:
        mid = (left + right) // 2  # find the mid
        if target < arr[mid]:
            right = mid
        elif target > arr[mid]:
            left = mid + 1
        else:
            return arr[mid]

    if target < arr[mid]:
        return find_closest(arr[mid - 1], arr[mid], target)
    else:
        return find_closest(arr[mid], arr[mid + 1], target)


# findClosest
# We find the closest by taking the difference
# between the target and both values. It assumes
# that val2 is greater than val1 and target lies
# between these two. 
def find_closest(val1, val2, target):
    return val2 if target - val1 >= val2 - target else val1

# function to find index using get_closest_value
# could probably optimise get_closest_value to just return the index, but maybe later
def index_finder(arr, target):
    if target > get_closest_value(arr, target):
         return arr.index(get_closest_value(arr,target))
    else:
        return arr.index(get_closest_value(arr, target))-1
    
def hsr(index):
    # Step 1) Get the category
    category_id = food_details['hsr_id'][index]

    # Step 2) Get the required columns
    energy = food_details['Energy, with dietary fibre (in kJ)'][index]
    tsfa = food_details['Total saturated fatty acids (in g)'][index]
    sugars = food_details['Total sugars (in g)'][index]
    sodium = food_details['Sodium (Na) (in mg)'][index]
    protein = food_details['Protein (in g)'][index]
    fibre = food_details['Total dietary fibre (in g)'][index]

    # Step 3) Calculate HSR Baseline Points
    # read tables in as lists
    if food_details['hsr_id'][index] == '1' or food_details['hsr_id'][index] == '1D' or food_details['hsr_id'][index] == '2' or food_details['hsr_id'][index] == '2D':
        hsr_energy = list(hsr_table_1['Energy content (kJ) per 100g or 100mL'])
        hsr_tsfa = list(hsr_table_1['Saturated fatty acids (g) per 100g or 100mL'])
        hsr_sugars = list(hsr_table_1['Total sugars (g) per 100g or 100mL'])
        hsr_sodium = list(hsr_table_1['Sodium (mg) per 100g or 100mL'])
    elif food_details['hsr_id'][index] == '3' or food_details['hsr_id'][index] == '3D': 
        hsr_energy = list(hsr_table_2['Energy content (kJ) per 100g or 100mL'])
        hsr_tsfa = list(hsr_table_2['Saturated fatty acids (g) per 100g or 100mL'])
        hsr_sugars = list(hsr_table_2['Total sugars (g) per 100g or 100mL'])
        hsr_sodium = list(hsr_table_2['Sodium (mg) per 100g or 100mL'])
    else:
        return numpy.nan
    

    # remove nans
    hsr_energy = [x for x in hsr_energy if str(x) != 'nan']
    hsr_tsfa = [x for x in hsr_tsfa if str(x) != 'nan']
    hsr_sugars = [x for x in hsr_sugars if str(x) != 'nan']
    hsr_sodium = [x for x in hsr_sodium if str(x) != 'nan']

    # need some way of quick of getting baseline points based on the table
    baseline_points = []
    baseline_points.append(index_finder(hsr_energy, energy))
    baseline_points.append(index_finder(hsr_tsfa, tsfa))
    baseline_points.append(index_finder(hsr_sugars, sugars))
    baseline_points.append(index_finder(hsr_sodium, sodium))

    # PICK MAX INDEX!!
    baseline_points.sort() 

    # Step 4) Modifying Points (P and F only since we don't have V points)
    # read in p and f tables
    hsr_p = list(hsr_table_3['Protein (g) per 100g or 100mL'])
    hsr_f = list(hsr_table_3['Dietary fibre (g) per 100g or 100mL'])

    p_points = index_finder(hsr_p, protein)
    f_points = index_finder(hsr_f, fibre)

    #Step 5) Calculate Final HSR Score
    final_hsr_score = baseline_points[-1] - p_points - f_points
    hsr = hsr_table_4['Health Star Rating'][list(hsr_table_4[category_id]).index(get_closest_value(list(hsr_table_4[category_id]), final_hsr_score))]
    
    return hsr

ingredient_hsr = []
worked = 0
not_worked = 0

for each in range(len(food_details)):
    try:
        ingredient_hsr.append(hsr(each))
        worked +=1
    except:
        ingredient_hsr.append(np.nan)
        not_worked +=1 
        
# need to write back to food_details 
food_details['hsr'] = ingredient_hsr

# %% [markdown]
# ## Joining to get GHG emissions

# %%
food_details = food_details.merge(food_emissions, on = ['emission_id'], how = 'left')

# %% [markdown]
# ## Filtering down 'food name' and dropping duplicates
# At the moment, the food_details table has all the information we need about particular ingredients,however the 'Name' column has a lot of 'duplicates' of ingredients, based on not much needed information.
#
# The goal here is to find by which comma can we split such that the difference in Energy (ie. the range between highest and lowest value), is appropriate.

# %%
# find the max number of separations in "Food Name" column
commas = []
for each in food_details["Food Name"]:
    commas.append(len(each.split(',')))

max(commas)

# split food
name_split = food_details["Food Name"].str.split(",", n = 9, expand = True)

food_details["name"] = name_split[0]
food_details["name1"] = name_split[1]
food_details["name2"] = name_split[2]
food_details["name3"] = name_split[3]
food_details["name4"] = name_split[4]
food_details["name5"] = name_split[5]
food_details["name6"] = name_split[6]
food_details["name7"] = name_split[7]
food_details["name8"] = name_split[8]
food_details["name9"] = name_split[9]

# function to calculate range
def mm_diff(x):
           return np.max(x) - np.min(x)
    
names = food_details[['name', 'name1', 'name2', 'name3', 'name4', 'name5', 'name6', 'name7', 'name8', 'name9','Energy, with dietary fibre (in kJ)']]
print('Grouping by name: ' + str(names.groupby('name').agg([mm_diff]).mean()))
print('Grouping by name1: ' + str(names.groupby(['name', 'name1']).agg([mm_diff]).mean()))
print('Grouping by name2: ' + str(names.groupby(['name', 'name1', 'name2']).agg([mm_diff]).mean()))
print('Grouping by name3: ' + str(names.groupby(['name', 'name1', 'name2', 'name3']).agg([mm_diff]).mean()))
print('Grouping by name4: ' + str(names.groupby(['name', 'name1', 'name2', 'name3', 'name4']).agg([mm_diff]).mean()))
print('Grouping by name5: ' + str(names.groupby(['name', 'name1', 'name2', 'name3', 'name4', 'name5']).agg([mm_diff]).mean()))
print('Grouping by name6: ' + str(names.groupby(['name', 'name1', 'name2', 'name3', 'name4', 'name5', 'name6']).agg([mm_diff]).mean()))
print('Grouping by name7: ' + str(names.groupby(['name', 'name1', 'name2', 'name3', 'name4', 'name5', 'name6', 'name7']).agg([mm_diff]).mean()))
print('Grouping by name8: ' + str(names.groupby(['name', 'name1', 'name2', 'name3', 'name4', 'name5', 'name6', 'name7', 'name8']).agg([mm_diff]).mean()))
print('Grouping by name9: ' + str(names.groupby(['name', 'name1', 'name2', 'name3', 'name4', 'name5', 'name6', 'name7', 'name8', 'name9']).agg([mm_diff]).mean()))
# Out:
# Grouping by name: Energy, with dietary fibre (in kJ)  mm_diff    265.771831
# dtype: float64
# Grouping by name1: Energy, with dietary fibre (in kJ)  mm_diff    104.449184
# dtype: float64
# Grouping by name2: Energy, with dietary fibre (in kJ)  mm_diff    57.403153
# dtype: float64
# Grouping by name3: Energy, with dietary fibre (in kJ)  mm_diff    24.626109
# dtype: float64
# Grouping by name4: Energy, with dietary fibre (in kJ)  mm_diff    22.076253
# dtype: float64
# Grouping by name5: Energy, with dietary fibre (in kJ)  mm_diff    1.171569
# dtype: float64
# Grouping by name6: Energy, with dietary fibre (in kJ)  mm_diff    0.0
# dtype: float64
# Grouping by name7: Energy, with dietary fibre (in kJ)  mm_diff    0.0
# dtype: float64
# Grouping by name8: Energy, with dietary fibre (in kJ)  mm_diff    0.0
# dtype: float64
# Grouping by name9: Energy, with dietary fibre (in kJ)  mm_diff    0.0
# dtype: float64

# %%
# As we can see from the analysis done above, if we only consider 1 comma, then our potential error will be approximately 100kj (which equates to around 20 calories)
# So, we should drop duplicates, based on name and name1 combination
food_details.drop_duplicates(subset = ['name', 'name1'], inplace=True, ignore_index=True)

# %% [markdown]
# ## Constructing the appropriate data model and posting to the API
# We should only send the columns that we need from our dataset:
#
# * name
# * name1 (to be called type)
# * Description
# * Energy, with dietary fibre (in kJ)
# * hsr
# * hsr_id
# * GHG Emissions (kg CO2eq/FU) (Mean)
# * emissions_id
# * Protein (in g)
# * Sodium (Na) (in mg)
# * Total sugars (in g)
# * Total saturated fatty acids (in g)
# * Total dietary fibre (in g)
# * Total Fat (in g)
# * Available carbohydrate, without sugar alcohols (in g)

# %%
# clean up the trailing whitespace
food_details["name1"] = food_details["name1"].str.lstrip()

# Need to clean up the Nones so it can be handled nicely by the API
food_details = food_details.replace({np.nan: None})

# cleanup food_details before we send to API
food_details.rename(columns={'name1': 'ingredient_type',\
                            'Description': 'description',\
                            'Energy, with dietary fibre (in kJ)': 'energy',\
                            'GHG Emissions (kg CO2eq/FU) (Mean)': 'ghg', \
                            'Protein (in g)': 'protein',\
                            'Sodium (Na) (in mg)': 'sodium',\
                            'Total sugars (in g)': 'sugar',\
                            'Total saturated fatty acids (in g)': 'saturated_fat',\
                            'Total dietary fibre (in g)': 'fibre',\
                            'Total Fat (in g)': 'fat',\
                            'Available carbohydrate, without sugar alcohols (in g)': 'carbohydrate'}, inplace=True)

# %%
# iterate on each row in the addresses dataset
error = []
for row in food_details.itertuples():
    # form the payload
    ingredient = {
        "name" : row.name, \
        "ingredient_type" : row.ingredient_type, \
        "description" : row.description, \
        "energy" : row.energy, \
        "hsr" : row.hsr, \
        "hsr_id" : row.hsr_id, \
        "ghg": row.ghg, \
        "emission_id" : row.emission_id, \
        "protein" : row.protein, \
        "sodium" : row.sodium, \
        "sugar" : row.sugar, \
        "saturated_fat" : row.saturated_fat, \
        "fibre" : row.fibre, \
        "fat" : row.fat, \
        "carbohydrate" : row.carbohydrate
    }
    
    # making the API call
    r = requests.post('https://gfood-api.azurewebsites.net/ingredients/add', json=ingredient)
    try:
        if r.status_code != 201:
            error.append(row)
            print("ERROR!")
            print(r.json())
        else:
            print(r.json())
    except:
        continue
# Out:
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cardamom seed', 'ingredient_type': 'dried', '_id': '5ec0c157aad24000434b9df4', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c157aad24000434b9df4'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Chilli (chili)', 'ingredient_type': 'dried', '_id': '5ec0c158aad24000434b9df5', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c158aad24000434b9df5'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cinnamon', 'ingredient_type': 'dried', '_id': '5ec0c159aad24000434b9df6', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c159aad24000434b9df6'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cloves', 'ingredient_type': 'dried', '_id': '5ec0c159aad24000434b9df7', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c159aad24000434b9df7'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Coriander seed', 'ingredient_type': 'dried', '_id': '5ec0c159aad24000434b9df8', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c159aad24000434b9df8'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cumin (cummin) seed', 'ingredient_type': 'dried', '_id': '5ec0c15aaad24000434b9df9', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c15aaad24000434b9df9'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Curry powder', 'ingredient_type': None, '_id': '5ec0c15aaad24000434b9dfa', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c15aaad24000434b9dfa'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Fenugreek seed', 'ingredient_type': 'dried', '_id': '5ec0c15aaad24000434b9dfb', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c15aaad24000434b9dfb'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Ginger', 'ingredient_type': 'dried', '_id': '5ec0c15baad24000434b9dfc', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c15baad24000434b9dfc'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Mustard powder', 'ingredient_type': None, '_id': '5ec0c15baad24000434b9dfd', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c15baad24000434b9dfd'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Nutmeg', 'ingredient_type': 'dried', '_id': '5ec0c15baad24000434b9dfe', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c15baad24000434b9dfe'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Oregano', 'ingredient_type': 'dried', '_id': '5ec0c15caad24000434b9dff', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c15caad24000434b9dff'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Paprika', 'ingredient_type': 'dry powder', '_id': '5ec0c15caad24000434b9e00', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c15caad24000434b9e00'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Pepper', 'ingredient_type': 'black', '_id': '5ec0c15caad24000434b9e01', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c15caad24000434b9e01'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Rosemary', 'ingredient_type': 'dried', '_id': '5ec0c15caad24000434b9e02', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c15caad24000434b9e02'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Sage', 'ingredient_type': 'dried', '_id': '5ec0c15daad24000434b9e03', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c15daad24000434b9e03'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Thyme', 'ingredient_type': 'dried', '_id': '5ec0c15daad24000434b9e04', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c15daad24000434b9e04'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Turmeric', 'ingredient_type': 'dried', '_id': '5ec0c15daad24000434b9e05', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c15daad24000434b9e05'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Salt substitute', 'ingredient_type': 'potassium chloride', '_id': '5ec0c15daad24000434b9e06', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c15daad24000434b9e06'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Salt', 'ingredient_type': 'table', '_id': '5ec0c15eaad24000434b9e07', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c15eaad24000434b9e07'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Stock', 'ingredient_type': 'dry powder or cube', '_id': '5ec0c15eaad24000434b9e08', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c15eaad24000434b9e08'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Taco seasoning mix', 'ingredient_type': 'chilli-based', '_id': '5ec0c15eaad24000434b9e09', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c15eaad24000434b9e09'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Baking powder', 'ingredient_type': 'dry powder', '_id': '5ec0c15faad24000434b9e0a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c15faad24000434b9e0a'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Baking soda (bicarbonate)', 'ingredient_type': 'dry powder', '_id': '5ec0c15faad24000434b9e0b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c15faad24000434b9e0b'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cream of tartar', 'ingredient_type': 'dry powder', '_id': '5ec0c15faad24000434b9e0c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c15faad24000434b9e0c'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Gelatine', 'ingredient_type': 'all types', '_id': '5ec0c160aad24000434b9e0d', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c160aad24000434b9e0d'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Gluten', 'ingredient_type': 'from wheat (vital wheat gluten)', '_id': '5ec0c160aad24000434b9e0e', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c160aad24000434b9e0e'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Starch', 'ingredient_type': 'potato', '_id': '5ec0c160aad24000434b9e0f', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c160aad24000434b9e0f'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Vanilla', 'ingredient_type': 'artificial or imitation', '_id': '5ec0c160aad24000434b9e10', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c160aad24000434b9e10'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Vanilla bean extract', 'ingredient_type': None, '_id': '5ec0c161aad24000434b9e11', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c161aad24000434b9e11'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Yeast', 'ingredient_type': 'dry powder', '_id': '5ec0c161aad24000434b9e12', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c161aad24000434b9e12'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Beer', 'ingredient_type': 'high alcohol (5% v/v & above)', '_id': '5ec0c161aad24000434b9e13', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c161aad24000434b9e13'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Beer', 'ingredient_type': 'full strength (alcohol 4-4.9% v/v)', '_id': '5ec0c162aad24000434b9e14', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c162aad24000434b9e14'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Beer', 'ingredient_type': 'mid-strength (alcohol 3-3.9% v/v)', '_id': '5ec0c162aad24000434b9e15', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c162aad24000434b9e15'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Beer', 'ingredient_type': 'light (alcohol 1- less than 3% v/v)', '_id': '5ec0c163aad24000434b9e16', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c163aad24000434b9e16'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Alcoholic beverage', 'ingredient_type': 'spirit', '_id': '5ec0c163aad24000434b9e17', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c163aad24000434b9e17'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cider', 'ingredient_type': 'apple (alcohol approximately 4-5% v/v)', '_id': '5ec0c163aad24000434b9e18', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c163aad24000434b9e18'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Wine', 'ingredient_type': 'red', '_id': '5ec0c163aad24000434b9e19', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c163aad24000434b9e19'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Wine', 'ingredient_type': 'rose', '_id': '5ec0c164aad24000434b9e1a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c164aad24000434b9e1a'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Wine', 'ingredient_type': 'white', '_id': '5ec0c164aad24000434b9e1b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c164aad24000434b9e1b'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Wine', 'ingredient_type': 'fortified', '_id': '5ec0c164aad24000434b9e1c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c164aad24000434b9e1c'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cocoa powder', 'ingredient_type': None, '_id': '5ec0c165aad24000434b9e1d', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c165aad24000434b9e1d'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Beverage base', 'ingredient_type': 'chocolate flavour', '_id': '5ec0c165aad24000434b9e1e', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c165aad24000434b9e1e'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Beverage', 'ingredient_type': 'chocolate flavour', '_id': '5ec0c165aad24000434b9e1f', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c165aad24000434b9e1f'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Beverage base', 'ingredient_type': 'drinking chocolate', '_id': '5ec0c165aad24000434b9e20', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c165aad24000434b9e20'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Coffee', 'ingredient_type': 'instant', '_id': '5ec0c166aad24000434b9e21', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c166aad24000434b9e21'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Coffee', 'ingredient_type': 'black', '_id': '5ec0c166aad24000434b9e22', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c166aad24000434b9e22'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Coffee', 'ingredient_type': 'espresso', '_id': '5ec0c166aad24000434b9e23', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c166aad24000434b9e23'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Coffee', 'ingredient_type': 'cappuccino', '_id': '5ec0c166aad24000434b9e24', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c166aad24000434b9e24'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Coffee', 'ingredient_type': 'flat white or latte', '_id': '5ec0c167aad24000434b9e25', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c167aad24000434b9e25'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Coffee', 'ingredient_type': 'long black', '_id': '5ec0c167aad24000434b9e26', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c167aad24000434b9e26'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cordial base', 'ingredient_type': '25% citrus fruit juice', '_id': '5ec0c167aad24000434b9e27', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c167aad24000434b9e27'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cordial', 'ingredient_type': '25% citrus fruit juice', '_id': '5ec0c168aad24000434b9e28', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c168aad24000434b9e28'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cordial base', 'ingredient_type': '40% citrus fruit juice', '_id': '5ec0c168aad24000434b9e29', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c168aad24000434b9e29'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cordial', 'ingredient_type': '40% citrus fruit juice', '_id': '5ec0c168aad24000434b9e2a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c168aad24000434b9e2a'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cordial base', 'ingredient_type': '5% blackcurrant juice', '_id': '5ec0c169aad24000434b9e2b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c169aad24000434b9e2b'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cordial', 'ingredient_type': '25% blackcurrant juice', '_id': '5ec0c169aad24000434b9e2c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c169aad24000434b9e2c'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Fruit drink', 'ingredient_type': 'apple juice', '_id': '5ec0c169aad24000434b9e2d', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c169aad24000434b9e2d'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Fruit drink', 'ingredient_type': 'cranberry', '_id': '5ec0c169aad24000434b9e2e', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c169aad24000434b9e2e'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Fruit drink', 'ingredient_type': 'orange juice', '_id': '5ec0c16aaad24000434b9e2f', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c16aaad24000434b9e2f'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Juice', 'ingredient_type': 'apple', '_id': '5ec0c16aaad24000434b9e30', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c16aaad24000434b9e30'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Juice', 'ingredient_type': 'apple & blackcurrant', '_id': '5ec0c16aaad24000434b9e31', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c16aaad24000434b9e31'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Juice', 'ingredient_type': 'lemon', '_id': '5ec0c16baad24000434b9e32', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c16baad24000434b9e32'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Juice', 'ingredient_type': 'lime', '_id': '5ec0c16baad24000434b9e33', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c16baad24000434b9e33'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Juice', 'ingredient_type': 'orange', '_id': '5ec0c16baad24000434b9e34', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c16baad24000434b9e34'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Juice', 'ingredient_type': 'orange & mango', '_id': '5ec0c16caad24000434b9e35', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c16caad24000434b9e35'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Mineral water', 'ingredient_type': 'natural', '_id': '5ec0c16caad24000434b9e36', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c16caad24000434b9e36'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Mineral water', 'ingredient_type': 'citrus flavoured', '_id': '5ec0c16caad24000434b9e37', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c16caad24000434b9e37'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Soft drink', 'ingredient_type': 'cola flavour', '_id': '5ec0c16daad24000434b9e38', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c16daad24000434b9e38'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Soft drink', 'ingredient_type': 'energy drink', '_id': '5ec0c16daad24000434b9e39', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c16daad24000434b9e39'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Soft drink', 'ingredient_type': 'lemonade and fruit flavours', '_id': '5ec0c16daad24000434b9e3a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c16daad24000434b9e3a'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Soft drink', 'ingredient_type': 'tonic water', '_id': '5ec0c16eaad24000434b9e3b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c16eaad24000434b9e3b'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Tea', 'ingredient_type': 'green', '_id': '5ec0c16eaad24000434b9e3c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c16eaad24000434b9e3c'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Tea', 'ingredient_type': 'regular', '_id': '5ec0c16eaad24000434b9e3d', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c16eaad24000434b9e3d'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Tea', 'ingredient_type': 'decaffeinated', '_id': '5ec0c16eaad24000434b9e3e', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c16eaad24000434b9e3e'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Water', 'ingredient_type': 'bottled', '_id': '5ec0c16faad24000434b9e3f', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c16faad24000434b9e3f'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Water', 'ingredient_type': 'tap', '_id': '5ec0c16faad24000434b9e40', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c16faad24000434b9e40'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Water', 'ingredient_type': 'soda', '_id': '5ec0c16faad24000434b9e41', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c16faad24000434b9e41'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Biscuit', 'ingredient_type': 'savoury', '_id': '5ec0c170aad24000434b9e42', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c170aad24000434b9e42'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Biscuit', 'ingredient_type': 'sweet', '_id': '5ec0c170aad24000434b9e43', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c170aad24000434b9e43'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cone', 'ingredient_type': 'wafer style', '_id': '5ec0c170aad24000434b9e44', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c170aad24000434b9e44'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Breadcrumbs', 'ingredient_type': 'white', '_id': '5ec0c170aad24000434b9e45', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c170aad24000434b9e45'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Bread', 'ingredient_type': 'damper', '_id': '5ec0c171aad24000434b9e46', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c171aad24000434b9e46'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Bread', 'ingredient_type': 'flat', '_id': '5ec0c171aad24000434b9e47', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c171aad24000434b9e47'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Bread', 'ingredient_type': 'flat (pita or Lebanese)', '_id': '5ec0c171aad24000434b9e48', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c171aad24000434b9e48'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Bread', 'ingredient_type': 'from white flour', '_id': '5ec0c171aad24000434b9e49', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c171aad24000434b9e49'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Bread', 'ingredient_type': 'from white Jackaroo flour', '_id': '5ec0c172aad24000434b9e4a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c172aad24000434b9e4a'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Bread roll', 'ingredient_type': 'from white flour', '_id': '5ec0c172aad24000434b9e4b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c172aad24000434b9e4b'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Bread roll', 'ingredient_type': 'topped with cheese', '_id': '5ec0c172aad24000434b9e4c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c172aad24000434b9e4c'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Bread roll', 'ingredient_type': 'topped with cheese & bacon', '_id': '5ec0c173aad24000434b9e4d', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c173aad24000434b9e4d'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Bread', 'ingredient_type': 'from wholemeal flour', '_id': '5ec0c173aad24000434b9e4e', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c173aad24000434b9e4e'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Bread roll', 'ingredient_type': 'from wholemeal flour', '_id': '5ec0c173aad24000434b9e4f', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c173aad24000434b9e4f'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Bread', 'ingredient_type': 'from white or wholemeal flour', '_id': '5ec0c173aad24000434b9e50', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c173aad24000434b9e50'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Bread', 'ingredient_type': 'mixed grain', '_id': '5ec0c174aad24000434b9e51', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c174aad24000434b9e51'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Bread roll', 'ingredient_type': 'mixed grain', '_id': '5ec0c174aad24000434b9e52', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c174aad24000434b9e52'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Bread', 'ingredient_type': 'from wheat flour', '_id': '5ec0c174aad24000434b9e53', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c174aad24000434b9e53'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Bread', 'ingredient_type': 'garlic or herb', '_id': '5ec0c175aad24000434b9e54', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c175aad24000434b9e54'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Bread', 'ingredient_type': 'gluten free', '_id': '5ec0c175aad24000434b9e55', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c175aad24000434b9e55'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Bread', 'ingredient_type': 'from rye flour', '_id': '5ec0c176aad24000434b9e56', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c176aad24000434b9e56'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Bun', 'ingredient_type': 'sweet', '_id': '5ec0c176aad24000434b9e57', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c176aad24000434b9e57'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Crumpet', 'ingredient_type': 'from white flour', '_id': '5ec0c176aad24000434b9e58', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c176aad24000434b9e58'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Muffin', 'ingredient_type': 'English style', '_id': '5ec0c176aad24000434b9e59', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c176aad24000434b9e59'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Breakfast cereal', 'ingredient_type': 'beverage', '_id': '5ec0c177aad24000434b9e5a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c177aad24000434b9e5a'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Breakfast cereal', 'ingredient_type': 'flakes of corn', '_id': '5ec0c177aad24000434b9e5b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c177aad24000434b9e5b'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Breakfast cereal', 'ingredient_type': 'mixed grain (rice & wheat)', '_id': '5ec0c177aad24000434b9e5c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c177aad24000434b9e5c'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Breakfast cereal', 'ingredient_type': 'mixed grain (wheat & oat)', '_id': '5ec0c178aad24000434b9e5d', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c178aad24000434b9e5d'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Breakfast cereal', 'ingredient_type': 'mixed grain (wheat', '_id': '5ec0c178aad24000434b9e5e', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c178aad24000434b9e5e'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Breakfast cereal', 'ingredient_type': 'puffed or popped rice', '_id': '5ec0c178aad24000434b9e5f', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c178aad24000434b9e5f'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Breakfast cereal', 'ingredient_type': 'wheat bran', '_id': '5ec0c178aad24000434b9e60', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c178aad24000434b9e60'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Breakfast cereal', 'ingredient_type': 'whole wheat', '_id': '5ec0c179aad24000434b9e61', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c179aad24000434b9e61'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Muesli', 'ingredient_type': 'toasted', '_id': '5ec0c179aad24000434b9e62', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c179aad24000434b9e62'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Muesli', 'ingredient_type': 'untoasted or natural style', '_id': '5ec0c179aad24000434b9e63', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c179aad24000434b9e63'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Bread', 'ingredient_type': 'banana', '_id': '5ec0c17aaad24000434b9e64', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c17aaad24000434b9e64'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Slice', 'ingredient_type': 'brownie', '_id': '5ec0c17aaad24000434b9e65', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c17aaad24000434b9e65'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cake mix', 'ingredient_type': 'plain', '_id': '5ec0c17aaad24000434b9e66', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c17aaad24000434b9e66'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cake', 'ingredient_type': 'carrot', '_id': '5ec0c17baad24000434b9e67', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c17baad24000434b9e67'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cake', 'ingredient_type': 'chocolate', '_id': '5ec0c17baad24000434b9e68', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c17baad24000434b9e68'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cake', 'ingredient_type': 'fruit', '_id': '5ec0c17baad24000434b9e69', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c17baad24000434b9e69'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cake', 'ingredient_type': 'lamington', '_id': '5ec0c17baad24000434b9e6a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c17baad24000434b9e6a'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cake', 'ingredient_type': 'mud', '_id': '5ec0c17caad24000434b9e6b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c17caad24000434b9e6b'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cake', 'ingredient_type': 'plain butter cake', '_id': '5ec0c17caad24000434b9e6c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c17caad24000434b9e6c'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cake', 'ingredient_type': 'sponge', '_id': '5ec0c17daad24000434b9e6d', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c17daad24000434b9e6d'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Doughnut', 'ingredient_type': 'jam filled', '_id': '5ec0c17daad24000434b9e6e', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c17daad24000434b9e6e'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Doughnut', 'ingredient_type': 'dusted with cinnamon & sugar', '_id': '5ec0c17daad24000434b9e6f', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c17daad24000434b9e6f'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Doughnut', 'ingredient_type': 'iced', '_id': '5ec0c17eaad24000434b9e70', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c17eaad24000434b9e70'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Muffin', 'ingredient_type': 'cake-style', '_id': '5ec0c17eaad24000434b9e71', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c17eaad24000434b9e71'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Pancake', 'ingredient_type': 'plain', '_id': '5ec0c17eaad24000434b9e72', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c17eaad24000434b9e72'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Pikelet or pancake', 'ingredient_type': 'sweet', '_id': '5ec0c17faad24000434b9e73', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c17faad24000434b9e73'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Pikelet', 'ingredient_type': 'plain', '_id': '5ec0c17faad24000434b9e74', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c17faad24000434b9e74'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Pudding', 'ingredient_type': 'chocolate', '_id': '5ec0c17faad24000434b9e75', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c17faad24000434b9e75'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Pudding', 'ingredient_type': 'plum', '_id': '5ec0c17faad24000434b9e76', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c17faad24000434b9e76'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Pudding', 'ingredient_type': 'sticky date', '_id': '5ec0c180aad24000434b9e77', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c180aad24000434b9e77'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Scone', 'ingredient_type': 'plain', '_id': '5ec0c180aad24000434b9e78', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c180aad24000434b9e78'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Scone', 'ingredient_type': 'fruit', '_id': '5ec0c180aad24000434b9e79', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c180aad24000434b9e79'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Scone', 'ingredient_type': 'pumpkin', '_id': '5ec0c180aad24000434b9e7a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c180aad24000434b9e7a'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Slice', 'ingredient_type': 'caramel', '_id': '5ec0c181aad24000434b9e7b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c181aad24000434b9e7b'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Buckwheat groats', 'ingredient_type': 'cooked in water', '_id': '5ec0c181aad24000434b9e7c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c181aad24000434b9e7c'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Porridge', 'ingredient_type': 'rolled oats', '_id': '5ec0c181aad24000434b9e7d', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c181aad24000434b9e7d'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Amaranth', 'ingredient_type': 'grain', '_id': '5ec0c182aad24000434b9e7e', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c182aad24000434b9e7e'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Barley', 'ingredient_type': 'pearl', '_id': '5ec0c182aad24000434b9e7f', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c182aad24000434b9e7f'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Buckwheat groats', 'ingredient_type': 'uncooked', '_id': '5ec0c182aad24000434b9e80', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c182aad24000434b9e80'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Bulgur', 'ingredient_type': 'uncooked', '_id': '5ec0c183aad24000434b9e81', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c183aad24000434b9e81'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Bulgur', 'ingredient_type': 'soaked in water', '_id': '5ec0c183aad24000434b9e82', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c183aad24000434b9e82'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cornmeal (polenta)', 'ingredient_type': 'uncooked', '_id': '5ec0c183aad24000434b9e83', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c183aad24000434b9e83'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Cornmeal (polenta)', 'ingredient_type': 'boiled', '_id': '5ec0c183aad24000434b9e84', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c183aad24000434b9e84'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Couscous', 'ingredient_type': 'uncooked', '_id': '5ec0c184aad24000434b9e85', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c184aad24000434b9e85'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Couscous', 'ingredient_type': 'boiled', '_id': '5ec0c184aad24000434b9e86', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c184aad24000434b9e86'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Millet', 'ingredient_type': 'uncooked', '_id': '5ec0c184aad24000434b9e87', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c184aad24000434b9e87'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Millet', 'ingredient_type': 'boiled', '_id': '5ec0c184aad24000434b9e88', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c184aad24000434b9e88'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Maize', 'ingredient_type': 'grits', '_id': '5ec0c185aad24000434b9e89', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c185aad24000434b9e89'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Oats', 'ingredient_type': 'hulled', '_id': '5ec0c185aad24000434b9e8a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c185aad24000434b9e8a'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Oats', 'ingredient_type': 'rolled', '_id': '5ec0c185aad24000434b9e8b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c185aad24000434b9e8b'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Psyllium', 'ingredient_type': 'uncooked', '_id': '5ec0c186aad24000434b9e8c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c186aad24000434b9e8c'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Quinoa', 'ingredient_type': 'black', '_id': '5ec0c186aad24000434b9e8d', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c186aad24000434b9e8d'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Quinoa', 'ingredient_type': 'red', '_id': '5ec0c186aad24000434b9e8e', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c186aad24000434b9e8e'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Quinoa', 'ingredient_type': 'white', '_id': '5ec0c187aad24000434b9e8f', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c187aad24000434b9e8f'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Quinoa', 'ingredient_type': 'uncooked', '_id': '5ec0c187aad24000434b9e90', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c187aad24000434b9e90'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Quinoa', 'ingredient_type': 'cooked in water', '_id': '5ec0c187aad24000434b9e91', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c187aad24000434b9e91'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Rye', 'ingredient_type': 'grain', '_id': '5ec0c187aad24000434b9e92', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c187aad24000434b9e92'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Rye', 'ingredient_type': 'rolled', '_id': '5ec0c188aad24000434b9e93', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c188aad24000434b9e93'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Sorghum', 'ingredient_type': 'grain', '_id': '5ec0c188aad24000434b9e94', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c188aad24000434b9e94'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Triticale', 'ingredient_type': 'grain', '_id': '5ec0c188aad24000434b9e95', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c188aad24000434b9e95'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Semolina', 'ingredient_type': 'uncooked', '_id': '5ec0c189aad24000434b9e96', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c189aad24000434b9e96'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Semolina', 'ingredient_type': 'boiled', '_id': '5ec0c189aad24000434b9e97', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c189aad24000434b9e97'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Spelt', 'ingredient_type': 'uncooked', '_id': '5ec0c189aad24000434b9e98', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c189aad24000434b9e98'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Spelt', 'ingredient_type': 'boiled', '_id': '5ec0c18aaad24000434b9e99', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c18aaad24000434b9e99'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Tapioca', 'ingredient_type': 'pearl or seed style', '_id': '5ec0c18aaad24000434b9e9a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c18aaad24000434b9e9a'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Wheat', 'ingredient_type': 'whole', '_id': '5ec0c18aaad24000434b9e9b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c18aaad24000434b9e9b'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Wheat bran', 'ingredient_type': 'unprocessed', '_id': '5ec0c18aaad24000434b9e9c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c18aaad24000434b9e9c'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Wheat germ', 'ingredient_type': None, '_id': '5ec0c18aaad24000434b9e9d', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c18aaad24000434b9e9d'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Rice', 'ingredient_type': 'white', '_id': '5ec0c18baad24000434b9e9e', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c18baad24000434b9e9e'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Rice', 'ingredient_type': 'brown', '_id': '5ec0c18baad24000434b9e9f', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c18baad24000434b9e9f'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Rice', 'ingredient_type': 'wild', '_id': '5ec0c18caad24000434b9ea0', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c18caad24000434b9ea0'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Rice paper wrapper', 'ingredient_type': 'soaked in water', '_id': '5ec0c18caad24000434b9ea1', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c18caad24000434b9ea1'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Flour', 'ingredient_type': 'arrowroot', '_id': '5ec0c18caad24000434b9ea2', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c18caad24000434b9ea2'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Flour', 'ingredient_type': 'cornflour', '_id': '5ec0c18daad24000434b9ea3', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c18daad24000434b9ea3'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Flour', 'ingredient_type': 'chickpea (besan)', '_id': '5ec0c18daad24000434b9ea4', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c18daad24000434b9ea4'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Flour', 'ingredient_type': 'rice', '_id': '5ec0c18daad24000434b9ea5', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c18daad24000434b9ea5'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Flour', 'ingredient_type': 'rye', '_id': '5ec0c18daad24000434b9ea6', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c18daad24000434b9ea6'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Flour', 'ingredient_type': 'soya', '_id': '5ec0c18daad24000434b9ea7', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c18daad24000434b9ea7'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Flour', 'ingredient_type': 'spelt', '_id': '5ec0c18eaad24000434b9ea8', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c18eaad24000434b9ea8'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Flour', 'ingredient_type': 'wheat', '_id': '5ec0c18eaad24000434b9ea9', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c18eaad24000434b9ea9'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Flour', 'ingredient_type': 'gluten free', '_id': '5ec0c18eaad24000434b9eaa', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c18eaad24000434b9eaa'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Hamburger', 'ingredient_type': 'white roll', '_id': '5ec0c18faad24000434b9eab', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c18faad24000434b9eab'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Hot dog', 'ingredient_type': 'bread roll', '_id': '5ec0c18faad24000434b9eac', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c18faad24000434b9eac'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Pizza', 'ingredient_type': 'cheese & tomato', '_id': '5ec0c18faad24000434b9ead', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c18faad24000434b9ead'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Pizza', 'ingredient_type': 'ham & pineapple', '_id': '5ec0c190aad24000434b9eae', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c190aad24000434b9eae'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Pizza', 'ingredient_type': 'supreme', '_id': '5ec0c190aad24000434b9eaf', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c190aad24000434b9eaf'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Pizza', 'ingredient_type': 'vegetable', '_id': '5ec0c190aad24000434b9eb0', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c190aad24000434b9eb0'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Noodle', 'ingredient_type': 'soba', '_id': '5ec0c190aad24000434b9eb1', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c190aad24000434b9eb1'}}}
# ...
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Lettuce', 'ingredient_type': 'cos', '_id': '5ec0c23eaad24000434ba0dd', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c23eaad24000434ba0dd'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Lettuce', 'ingredient_type': 'iceberg', '_id': '5ec0c23eaad24000434ba0de', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c23eaad24000434ba0de'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Lettuce', 'ingredient_type': 'mignonette', '_id': '5ec0c23eaad24000434ba0df', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c23eaad24000434ba0df'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Melon', 'ingredient_type': 'bitter', '_id': '5ec0c23eaad24000434ba0e0', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c23eaad24000434ba0e0'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Melon', 'ingredient_type': 'hairy', '_id': '5ec0c23faad24000434ba0e1', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c23faad24000434ba0e1'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Mint', 'ingredient_type': 'fresh', '_id': '5ec0c23faad24000434ba0e2', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c23faad24000434ba0e2'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Mixed vegetables', 'ingredient_type': 'purchased frozen', '_id': '5ec0c23faad24000434ba0e3', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c23faad24000434ba0e3'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Mushroom', 'ingredient_type': 'common', '_id': '5ec0c240aad24000434ba0e4', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c240aad24000434ba0e4'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Okra', 'ingredient_type': 'raw', '_id': '5ec0c240aad24000434ba0e5', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c240aad24000434ba0e5'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Okra', 'ingredient_type': 'cooked', '_id': '5ec0c240aad24000434ba0e6', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c240aad24000434ba0e6'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Olive', 'ingredient_type': 'green or black', '_id': '5ec0c241aad24000434ba0e7', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c241aad24000434ba0e7'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Onion', 'ingredient_type': 'mature', '_id': '5ec0c241aad24000434ba0e8', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c241aad24000434ba0e8'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Onion', 'ingredient_type': 'spring', '_id': '5ec0c241aad24000434ba0e9', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c241aad24000434ba0e9'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Parsley', 'ingredient_type': 'continental', '_id': '5ec0c242aad24000434ba0ea', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c242aad24000434ba0ea'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Parsley', 'ingredient_type': 'curly', '_id': '5ec0c242aad24000434ba0eb', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c242aad24000434ba0eb'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Parsnip', 'ingredient_type': 'peeled', '_id': '5ec0c242aad24000434ba0ec', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c242aad24000434ba0ec'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Potato', 'ingredient_type': 'chips', '_id': '5ec0c242aad24000434ba0ed', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c242aad24000434ba0ed'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Potato', 'ingredient_type': 'coliban', '_id': '5ec0c243aad24000434ba0ee', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c243aad24000434ba0ee'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Potato', 'ingredient_type': 'desiree', '_id': '5ec0c243aad24000434ba0ef', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c243aad24000434ba0ef'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Potato', 'ingredient_type': 'new', '_id': '5ec0c243aad24000434ba0f0', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c243aad24000434ba0f0'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Potato', 'ingredient_type': 'pale skin', '_id': '5ec0c243aad24000434ba0f1', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c243aad24000434ba0f1'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Potato', 'ingredient_type': 'pontiac', '_id': '5ec0c244aad24000434ba0f2', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c244aad24000434ba0f2'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Potato', 'ingredient_type': 'red skin', '_id': '5ec0c244aad24000434ba0f3', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c244aad24000434ba0f3'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Potato', 'ingredient_type': 'sebago', '_id': '5ec0c244aad24000434ba0f4', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c244aad24000434ba0f4'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Potato', 'ingredient_type': 'fries', '_id': '5ec0c245aad24000434ba0f5', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c245aad24000434ba0f5'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Pumpkin', 'ingredient_type': 'butternut', '_id': '5ec0c245aad24000434ba0f6', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c245aad24000434ba0f6'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Pumpkin', 'ingredient_type': 'golden nugget', '_id': '5ec0c245aad24000434ba0f7', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c245aad24000434ba0f7'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Pumpkin', 'ingredient_type': 'jarrahdale', '_id': '5ec0c246aad24000434ba0f8', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c246aad24000434ba0f8'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Pumpkin', 'ingredient_type': 'peeled', '_id': '5ec0c246aad24000434ba0f9', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c246aad24000434ba0f9'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Pumpkin', 'ingredient_type': 'Queensland blue', '_id': '5ec0c246aad24000434ba0fa', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c246aad24000434ba0fa'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Radish', 'ingredient_type': 'red skinned', '_id': '5ec0c246aad24000434ba0fb', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c246aad24000434ba0fb'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Radish', 'ingredient_type': 'white skinned', '_id': '5ec0c247aad24000434ba0fc', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c247aad24000434ba0fc'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Rocket', 'ingredient_type': 'fresh', '_id': '5ec0c247aad24000434ba0fd', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c247aad24000434ba0fd'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Rosemary', 'ingredient_type': 'fresh', '_id': '5ec0c247aad24000434ba0fe', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c247aad24000434ba0fe'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Seaweed', 'ingredient_type': 'nori', '_id': '5ec0c247aad24000434ba0ff', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c247aad24000434ba0ff'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Seaweed', 'ingredient_type': 'boiled', '_id': '5ec0c248aad24000434ba100', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c248aad24000434ba100'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Shallot', 'ingredient_type': 'peeled', '_id': '5ec0c248aad24000434ba101', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c248aad24000434ba101'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Silverbeet', 'ingredient_type': 'fresh', '_id': '5ec0c248aad24000434ba102', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c248aad24000434ba102'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Snow pea', 'ingredient_type': 'fresh', '_id': '5ec0c249aad24000434ba103', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c249aad24000434ba103'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Spinach', 'ingredient_type': 'baby', '_id': '5ec0c249aad24000434ba104', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c249aad24000434ba104'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Spinach', 'ingredient_type': 'Mature English', '_id': '5ec0c249aad24000434ba105', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c249aad24000434ba105'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Spinach', 'ingredient_type': 'water', '_id': '5ec0c249aad24000434ba106', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c249aad24000434ba106'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Sprout', 'ingredient_type': 'alfalfa', '_id': '5ec0c24aaad24000434ba107', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c24aaad24000434ba107'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Sprout', 'ingredient_type': 'bean', '_id': '5ec0c24aaad24000434ba108', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c24aaad24000434ba108'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Squash', 'ingredient_type': 'button', '_id': '5ec0c24aaad24000434ba109', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c24aaad24000434ba109'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Squash', 'ingredient_type': 'scallopini', '_id': '5ec0c24baad24000434ba10a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c24baad24000434ba10a'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Swede', 'ingredient_type': 'peeled', '_id': '5ec0c24baad24000434ba10b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c24baad24000434ba10b'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Sweet potato', 'ingredient_type': 'orange flesh', '_id': '5ec0c24baad24000434ba10c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c24baad24000434ba10c'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Tamarind', 'ingredient_type': 'paste', '_id': '5ec0c24caad24000434ba10d', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c24caad24000434ba10d'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Taro', 'ingredient_type': 'peeled', '_id': '5ec0c24caad24000434ba10e', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c24caad24000434ba10e'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Tomato', 'ingredient_type': 'cherry', '_id': '5ec0c24caad24000434ba10f', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c24caad24000434ba10f'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Tomato', 'ingredient_type': 'common', '_id': '5ec0c24daad24000434ba110', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c24daad24000434ba110'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Tomato', 'ingredient_type': 'roma', '_id': '5ec0c24daad24000434ba111', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c24daad24000434ba111'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Tomato', 'ingredient_type': 'paste', '_id': '5ec0c24eaad24000434ba112', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c24eaad24000434ba112'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Tomato', 'ingredient_type': 'puree', '_id': '5ec0c24eaad24000434ba113', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c24eaad24000434ba113'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Tomato', 'ingredient_type': 'sundried', '_id': '5ec0c24eaad24000434ba114', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c24eaad24000434ba114'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Tomato', 'ingredient_type': 'whole', '_id': '5ec0c24eaad24000434ba115', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c24eaad24000434ba115'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Turnip', 'ingredient_type': 'white', '_id': '5ec0c24faad24000434ba116', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c24faad24000434ba116'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Vine leaf', 'ingredient_type': 'grape', '_id': '5ec0c24faad24000434ba117', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c24faad24000434ba117'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Water chestnut', 'ingredient_type': 'peeled', '_id': '5ec0c24faad24000434ba118', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c24faad24000434ba118'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Watercress', 'ingredient_type': 'raw', '_id': '5ec0c250aad24000434ba119', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c250aad24000434ba119'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Yam', 'ingredient_type': 'wild harvested', '_id': '5ec0c250aad24000434ba11a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c250aad24000434ba11a'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Zucchini', 'ingredient_type': 'green skin', '_id': '5ec0c250aad24000434ba11b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c250aad24000434ba11b'}}}
# {'message': 'Ingredient Added', 'addedIngredient': {'name': 'Zucchini', 'ingredient_type': 'golden', '_id': '5ec0c251aad24000434ba11c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/ingredients/5ec0c251aad24000434ba11c'}}}
